# %%
import numpy as np
import pandas as pd

df = pd.read_csv("./datasets/datos02a_train.csv")
x_train = df.drop(columns="ActividadFisica")
y_train = df[["ActividadFisica"]]

# %%
from sklearn.neighbors import KNeighborsClassifier

modelo = KNeighborsClassifier(n_neighbors=3)
modelo.fit(x_train, y_train)
# Out:
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=3)

# %%
persona = [90, 180, 25, 15]

# %%
x_test = pd.read_csv("./datasets/datos02a_test.csv")
y_test = pd.read_csv("./datasets/datos02a_test_etiquetas.csv")

# %%
modelo2 = KNeighborsClassifier(n_neighbors=3)

modelo2.fit(x_train[["Peso", "Estatura"]], y_train)

y_pred = modelo2.predict(x_test)
# Out:
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_pred, y_test)
# Out:
# 0.6

# %% [markdown]
# # Ejercicio 1

# %%
b2_train = pd.read_csv("./datasets/datos02b_train.csv")
b2_test = pd.read_csv("./datasets/datos02a_test.csv")

X_train = b2_train[["Peso", "Estatura"]]
Y_train = b2_train["ActividadFisica"]

modelo3 = KNeighborsClassifier(n_neighbors=5)

modelo3.fit(X_train, Y_train)

b2_pred = modelo3.predict(b2_test)

accuracy_score(b2_pred, y_test)
# Out:
# 0.4

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

estandarizador = StandardScaler()

estandarizador.fit(X_train, Y_train)

X_train = estandarizador.transform(X_train)

# %%
df = pd.read_csv("./datasets/datos05_train.csv")
X_train = df.drop(columns=["ActividadFisica"])
y_train = df["ActividadFisica"]

# %%
from sklearn.impute import SimpleImputer

imputer = ColumnTransformer(transformers=[
    ("num", SimpleImputer(strategy="mean"), ['Peso', 'Estatura', 'Edad', 'PctGrasaCorporal']),
    ("cat", SimpleImputer(strategy="most_frequent"), ['EstadoCivil'])
])

X_train = imputer.fit_transform(X_train, Y_train)
X_train = pd.DataFrame(data=X_train, columns=['Peso', 'Estatura', 'Edad', 'PctGrasaCorporal', 'EstadoCivil'])

preprocesador = ColumnTransformer(transformers=[
    ("num", StandardScaler(), ['Peso', 'Estatura', 'Edad', 'PctGrasaCorporal']),
    ("cat", OneHotEncoder(), ['EstadoCivil'])
])

X_train = preprocesador.fit_transform(X_train, Y_train)

# %%
df = pd.read_csv("./datasets/MathLearningDataset.csv")
X_train = df.drop(columns=["Student ID", "Question ID", "Type of Answer"])
y_train = df["Type of Answer"]
#df.isnull().sum()

imputer = ColumnTransformer(transformers=[
    ("num", SimpleImputer(strategy="mean"), ['Student Age', 'Response Time (s)']),
    ("cat", SimpleImputer(strategy="most_frequent"), ['Student Country', 'Question Level', 'Topic', 'Subtopic'])
])

X_train = imputer.fit_transform(X_train, Y_train)
X_train = pd.DataFrame(data=X_train, columns=['Student Country', 'Question Level', 'Topic', 'Subtopic', 'Student Age','Response Time (s)'])

pre = ColumnTransformer(transformers=[
    ("num", StandardScaler(), ['Student Age', 'Response Time (s)']),
    ("cat", OneHotEncoder(), ['Student Country', 'Question Level', 'Topic', 'Subtopic'])
])

X_train = pre.fit_transform(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13748\2004210465.py in ?()
#      15     ("num", StandardScaler(), ['Student Age', 'Response Time (s)']),
#      16     ("cat", OneHotEncoder(), ['Student Country', 'Question Level', 'Topic', 'Subtopic'])
#      17 ])
#      18
# ---> 19 X_train = pre.fit_transform(X_train, Y_train)
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, X, y, **params)
#     972             routed_params = process_routing(self, "fit_transform", **params)
#     973         else:
#     974             routed_params = self._get_empty_routing()
#     975
# --> 976         result = self._call_func_on_transformers(
#     977             X,
#     978             y,
#     979             _fit_transform_one,
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, X, y, func, column_as_labels, routed_params)
#     887         except ValueError as e:
#     888             if "Expected 2D array, got 1D array instead" in str(e):
#     889                 raise ValueError(_ERR_MSG_1DCOLUMN) from e
#     890             else:
# --> 891                 raise
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\utils\parallel.py in ?(self, iterable)
#      70         iterable_with_config = (
#      71             (_with_config(delayed_func, config), args, kwargs)
#      72             for delayed_func, args, kwargs in iterable
#      73         )
# ---> 74         return super().__call__(iterable_with_config)
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\joblib\parallel.py in ?(self, iterable)
#    1914             # If n_jobs==1, run the computation sequentially and return
#    1915             # immediately to avoid overheads.
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#    1921         # call is interrupted early and that the same instance is immediately
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\joblib\parallel.py in ?(self, iterable)
#    1857         finally:
#    1858             self.print_progress()
#    1859             self._running = False
#    1860             self._iterating = False
# -> 1861             self._original_iterator = None
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\utils\parallel.py in ?(self, *args, **kwargs)
#     132                 UserWarning,
#     133             )
#     134             config = {}
#     135         with config_context(**config):
# --> 136             return self.function(*args, **kwargs)
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\pipeline.py in ?(transformer, X, y, weight, message_clsname, message, params)
#    1306     """
#    1307     params = params or {}
#    1308     with _print_elapsed_time(message_clsname, message):
#    1309         if hasattr(transformer, "fit_transform"):
# -> 1310             res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1311         else:
#    1312             res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1313                 X, **params.get("transform", {})
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#     319             return_tuple = (
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1097             # fit method of arity 1 (unsupervised transformation)
#    1098             return self.fit(X, **fit_params).transform(X)
#    1099         else:
#    1100             # fit method of arity 2 (supervised transformation)
# -> 1101             return self.fit(X, y, **fit_params).transform(X)
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     874             Fitted scaler.
#     875         """
#     876         # Reset internal state before fitting
#     877         self._reset()
# --> 878         return self.partial_fit(X, y, sample_weight)
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y, sample_weight)
#     910         self : object
#     911             Fitted scaler.
#     912         """
#     913         first_call = not hasattr(self, "n_samples_seen_")
# --> 914         X = self._validate_data(
#     915             X,
#     916             accept_sparse=("csr", "csc"),
#     917             dtype=FLOAT_DTYPES,
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     741         # Use NumPy API to support order
#     742         if copy is True:
#     743             array = numpy.array(array, order=order, dtype=dtype)
#     744         else:
# --> 745             array = numpy.asarray(array, order=order, dtype=dtype)
#     746
#     747         # At this point array is a NumPy ndarray. We convert it to an array
#     748         # container that is consistent with the input's namespace.
#
# c:\Users\UO287561\Desktop\SI\sis_int\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'Statistics'
